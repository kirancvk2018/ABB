# %% [markdown]
# <a href="https://colab.research.google.com/github/kirancvk2018/ABB/blob/main/Python_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("kiran")
# Out:
# kiran

# %% [markdown]
# # I am leaning Python
# ##  I am leaning Python
# ###  I am leaning Python
#
# # print("kiran")
